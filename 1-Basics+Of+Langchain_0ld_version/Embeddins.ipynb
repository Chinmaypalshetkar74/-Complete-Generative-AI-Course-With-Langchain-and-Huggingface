# %% [markdown]
# #### Embedding Techniques
#
# Converting text into vectors

# %%
import os
from dotenv import load_dotenv
load_dotenv()  #load all the environment variables
# Out:
# True

# %%
import os
from dotenv import load_dotenv

# 1. Variables set in the terminal are ALREADY available.
# You do NOT need load_dotenv() for these.
db_user = os.getenv("DB_USER") 
print(f"Terminal Var: {db_user}")

# 2. load_dotenv() is ONLY for loading from a .env file 
# if the variable is MISSING from the terminal.
# It returns False if no file is found, but doesn't break existing vars.
load_dotenv()
# Out:
# Terminal Var: None
# True
